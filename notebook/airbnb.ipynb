# %% [markdown]
# ### Airbnb with Pyspark

# %% [markdown]
# ##### Creating a Spark Session

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
    .appName("Unpacking Airbnb data")\
    .getOrCreate()
# Out:
# 26/01/31 09:18:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# #### Importing the listing data

# %%
listings = spark.read.csv("../data/listings.csv.gz",
            header=True,
            inferSchema=True, ## to use the data actual schema
            sep = ",",
            quote = '"' ,
            escape = '"',
            multiLine= True,
            mode = "PERMISSIVE"
)

# %% [markdown]
# #### Getting the schema of the listing data

# %%
for list in listings.schema:
    print(list)
# Out:
# StructField('id', LongType(), True)
# StructField('listing_url', StringType(), True)
# StructField('scrape_id', LongType(), True)
# StructField('last_scraped', DateType(), True)
# StructField('source', StringType(), True)
# StructField('name', StringType(), True)
# StructField('description', StringType(), True)
# StructField('neighborhood_overview', StringType(), True)
# StructField('picture_url', StringType(), True)
# StructField('host_id', IntegerType(), True)
# StructField('host_url', StringType(), True)
# StructField('host_name', StringType(), True)
# StructField('host_since', DateType(), True)
# StructField('host_location', StringType(), True)
# StructField('host_about', StringType(), True)
# StructField('host_response_time', StringType(), True)
# StructField('host_response_rate', StringType(), True)
# StructField('host_acceptance_rate', StringType(), True)
# StructField('host_is_superhost', StringType(), True)
# StructField('host_thumbnail_url', StringType(), True)
# StructField('host_picture_url', StringType(), True)
# StructField('host_neighbourhood', StringType(), True)
# StructField('host_listings_count', IntegerType(), True)
# StructField('host_total_listings_count', IntegerType(), True)
# StructField('host_verifications', StringType(), True)
# StructField('host_has_profile_pic', StringType(), True)
# StructField('host_identity_verified', StringType(), True)
# StructField('neighbourhood', StringType(), True)
# StructField('neighbourhood_cleansed', StringType(), True)
# StructField('neighbourhood_group_cleansed', StringType(), True)
# StructField('latitude', DoubleType(), True)
# StructField('longitude', DoubleType(), True)
# StructField('property_type', StringType(), True)
# StructField('room_type', StringType(), True)
# StructField('accommodates', IntegerType(), True)
# StructField('bathrooms', DoubleType(), True)
# StructField('bathrooms_text', StringType(), True)
# StructField('bedrooms', IntegerType(), True)
# StructField('beds', IntegerType(), True)
# StructField('amenities', StringType(), True)
# StructField('price', StringType(), True)
# StructField('minimum_nights', IntegerType(), True)
# StructField('maximum_nights', IntegerType(), True)
# StructField('minimum_minimum_nights', IntegerType(), True)
# StructField('maximum_minimum_nights', IntegerType(), True)
# StructField('minimum_maximum_nights', IntegerType(), True)
# StructField('maximum_maximum_nights', IntegerType(), True)
# StructField('minimum_nights_avg_ntm', DoubleType(), True)
# StructField('maximum_nights_avg_ntm', DoubleType(), True)
# StructField('calendar_updated', StringType(), True)
# StructField('has_availability', StringType(), True)
# StructField('availability_30', IntegerType(), True)
# StructField('availability_60', IntegerType(), True)
# StructField('availability_90', IntegerType(), True)
# StructField('availability_365', IntegerType(), True)
# StructField('calendar_last_scraped', DateType(), True)
# StructField('number_of_reviews', IntegerType(), True)
# StructField('number_of_reviews_ltm', IntegerType(), True)
# StructField('number_of_reviews_l30d', IntegerType(), True)
# StructField('availability_eoy', IntegerType(), True)
# StructField('number_of_reviews_ly', IntegerType(), True)
# StructField('estimated_occupancy_l365d', IntegerType(), True)
# StructField('estimated_revenue_l365d', IntegerType(), True)
# StructField('first_review', DateType(), True)
# StructField('last_review', DateType(), True)
# StructField('review_scores_rating', DoubleType(), True)
# StructField('review_scores_accuracy', DoubleType(), True)
# StructField('review_scores_cleanliness', DoubleType(), True)
# StructField('review_scores_checkin', DoubleType(), True)
# StructField('review_scores_communication', DoubleType(), True)
# StructField('review_scores_location', DoubleType(), True)
# StructField('review_scores_value', DoubleType(), True)
# StructField('license', StringType(), True)
# StructField('instant_bookable', StringType(), True)
# StructField('calculated_host_listings_count', IntegerType(), True)
# StructField('calculated_host_listings_count_entire_homes', IntegerType(), True)
# StructField('calculated_host_listings_count_private_rooms', IntegerType(), True)
# StructField('calculated_host_listings_count_shared_rooms', IntegerType(), True)
# StructField('reviews_per_month', DoubleType(), True)

# %%
neighbourhoods = listings.select(listings.neighbourhood_cleansed)
neighbourhoods.show(20, truncate=False)
# Out:
# +----------------------+
# |neighbourhood_cleansed|
# +----------------------+
# |Islington             |
# |Kensington and Chelsea|
# |Westminster           |
# |Wandsworth            |
# |Tower Hamlets         |
# |Richmond upon Thames  |
# |Haringey              |
# |Hammersmith and Fulham|
# |Hammersmith and Fulham|
# |Southwark             |
# |Westminster           |
# |Barnet                |
# |Hounslow              |
# |Southwark             |
# |Waltham Forest        |
# |Barnet                |
# |Hammersmith and Fulham|
# |Hammersmith and Fulham|
# |Brent                 |
# |Camden                |
# +----------------------+
# only showing top 20 rows

# %%
review_locations = listings.select(listings.review_scores_rating)
review_locations.show()
# Out:
# +--------------------+
# |review_scores_rating|
# +--------------------+
# |                4.85|
# |                 4.8|
# |                4.77|
# |                 4.9|
# |                4.53|
# |                 4.8|
# |                4.87|
# |                4.77|
# |                4.83|
# |                4.97|
# |                 4.5|
# |                 4.5|
# |                 4.5|
# |                 4.7|
# |                 4.5|
# |                4.89|
# |                NULL|
# |                4.74|
# |                4.88|
# |                 5.0|
# +--------------------+
# only showing top 20 rows

# %%
listings \
    .select(listings.review_scores_location)\
    .show()
# Out:
# +----------------------+
# |review_scores_location|
# +----------------------+
# |                  4.78|
# |                  4.93|
# |                  4.89|
# |                   4.6|
# |                  4.85|
# |                   4.9|
# |                  4.77|
# |                  4.53|
# |                  4.79|
# |                  4.79|
# |                   4.5|
# |                  4.64|
# |                  4.84|
# |                  4.86|
# |                   4.0|
# |                  4.75|
# |                  NULL|
# |                  4.66|
# |                  4.67|
# |                   5.0|
# +----------------------+
# only showing top 20 rows

# %% [markdown]
# ##### SHOWING THE LOCATIONS WITH THE BEST RATINGS

# %%
high_score_listings = listings \
        .filter(listings.review_scores_location > 4.5)\
        .select('id','price','name','review_scores_location','review_scores_rating')

high_score_listings.show(20, truncate=False)
# Out:
# +-----+-------+-------------------------------------------------+----------------------+--------------------+
# |id   |price  |name                                             |review_scores_location|review_scores_rating|
# +-----+-------+-------------------------------------------------+----------------------+--------------------+
# |13913|$70.00 |Holiday London DB Room Let-on going              |4.78                  |4.85                |
# |15400|$149.00|Bright Chelsea  Apartment. Chelsea!              |4.93                  |4.8                 |
# |17402|$411.00|Very Central Modern 3-Bed/2 Bath By Oxford St W1 |4.89                  |4.77                |
# |24328|NULL   |Battersea live/work artist house                 |4.6                   |4.9                 |
# |36274|$210.00|Bright 1 bedroom apt off brick lane in Shoreditch|4.85                  |4.53                |
# |36299|$280.00|Kew Gardens 3BR house in cul-de-sac              |4.9                   |4.8                 |
# |36660|$90.00 |You are GUARANTEED to love this                  |4.77                  |4.87                |
# |38605|$61.00 |SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST       |4.53                  |4.77                |
# |38610|$340.00|Short Term Home                                  |4.79                  |4.83                |
# |38995|$49.00 |SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT         |4.79                  |4.97                |
# |41445|$213.00|2 Double bed apartment in quiet area North London|4.64                  |4.5                 |
# |41509|NULL   |Room in maisonette in chiswick                   |4.84                  |4.5                 |
# |41712|$96.00 |Room with a view, shared flat,  central  Bankside|4.86                  |4.7                 |
# |42010|$71.00 |You Will Save Money Here                         |4.75                  |4.89                |
# |43129|$48.00 |Quiet Comfortable Room in Fulham                 |4.66                  |4.74                |
# |43202|NULL   |Beautiful 1 bed apt in Queens Park               |4.67                  |4.88                |
# |45163|$76.00 |Room with a garden                               |5.0                   |5.0                 |
# |45168|NULL   |Best Part of Town -Home from Home!               |4.94                  |4.82                |
# |46992|NULL   |Beautiful, Luxurious Art Deco  +private bathroom |4.66                  |4.85                |
# |47192|$50.00 |Pleasant Single Room in zone 1.                  |4.77                  |4.81                |
# +-----+-------+-------------------------------------------------+----------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ##### REMOVING NULL VALUES FROM THE HIGHSCORE LISTING INSTANCE

# %%
high_score_listings.dropna().show(20, truncate=False)
# Out:
# +-----+-------+--------------------------------------------------+----------------------+--------------------+
# |id   |price  |name                                              |review_scores_location|review_scores_rating|
# +-----+-------+--------------------------------------------------+----------------------+--------------------+
# |13913|$70.00 |Holiday London DB Room Let-on going               |4.78                  |4.85                |
# |15400|$149.00|Bright Chelsea  Apartment. Chelsea!               |4.93                  |4.8                 |
# |17402|$411.00|Very Central Modern 3-Bed/2 Bath By Oxford St W1  |4.89                  |4.77                |
# |36274|$210.00|Bright 1 bedroom apt off brick lane in Shoreditch |4.85                  |4.53                |
# |36299|$280.00|Kew Gardens 3BR house in cul-de-sac               |4.9                   |4.8                 |
# |36660|$90.00 |You are GUARANTEED to love this                   |4.77                  |4.87                |
# |38605|$61.00 |SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST        |4.53                  |4.77                |
# |38610|$340.00|Short Term Home                                   |4.79                  |4.83                |
# |38995|$49.00 |SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT          |4.79                  |4.97                |
# |41445|$213.00|2 Double bed apartment in quiet area North London |4.64                  |4.5                 |
# |41712|$96.00 |Room with a view, shared flat,  central  Bankside |4.86                  |4.7                 |
# |42010|$71.00 |You Will Save Money Here                          |4.75                  |4.89                |
# |43129|$48.00 |Quiet Comfortable Room in Fulham                  |4.66                  |4.74                |
# |45163|$76.00 |Room with a garden                                |5.0                   |5.0                 |
# |47192|$50.00 |Pleasant Single Room in zone 1.                   |4.77                  |4.81                |
# |47687|$78.00 |Cosy Double studio in Zone 2 Hammersmith (6)      |4.91                  |4.73                |
# |49970|$79.00 |Beautiful Small Studio Hammersmith                |4.86                  |4.71                |
# |52624|$86.00 |Close to Wimbledon All England Tennis -huge double|4.95                  |4.95                |
# |56229|$78.00 |Cosy Double studio in Zone 2 Hammersmith (1)      |4.93                  |4.71                |
# |63948|$89.00 |Cosy Double studio in Zone 2 Hammersmith (4)      |4.91                  |4.63                |
# +-----+-------+--------------------------------------------------+----------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ##### CONVERTING THE PRICES TO FLOAT FROM STRING VALUES ATTACHED USING REGEX

# %%
from pyspark.sql.functions import regexp_replace
price_num_df = listings \
    .withColumn('price_num',regexp_replace('price','[$,]','').cast('float'))
price_num_df.schema['price_num']
# Out:
# StructField('price_num', FloatType(), True)

# %%
price_num_df\
    .select('price_num','name','review_scores_rating')\
    .show(20, truncate=False)
# Out:
# +---------+-------------------------------------------------+--------------------+
# |price_num|name                                             |review_scores_rating|
# +---------+-------------------------------------------------+--------------------+
# |70.0     |Holiday London DB Room Let-on going              |4.85                |
# |149.0    |Bright Chelsea  Apartment. Chelsea!              |4.8                 |
# |411.0    |Very Central Modern 3-Bed/2 Bath By Oxford St W1 |4.77                |
# |NULL     |Battersea live/work artist house                 |4.9                 |
# |210.0    |Bright 1 bedroom apt off brick lane in Shoreditch|4.53                |
# |280.0    |Kew Gardens 3BR house in cul-de-sac              |4.8                 |
# |90.0     |You are GUARANTEED to love this                  |4.87                |
# |61.0     |SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST       |4.77                |
# |340.0    |Short Term Home                                  |4.83                |
# |49.0     |SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT         |4.97                |
# |NULL     |Stylish bedsit in Notting Hill ish flat.         |4.5                 |
# |213.0    |2 Double bed apartment in quiet area North London|4.5                 |
# |NULL     |Room in maisonette in chiswick                   |4.5                 |
# |96.0     |Room with a view, shared flat,  central  Bankside|4.7                 |
# |NULL     |Room in relaxed family house!                    |4.5                 |
# |71.0     |You Will Save Money Here                         |4.89                |
# |NULL     |Fabulous flat w garden and bkfst!                |NULL                |
# |48.0     |Quiet Comfortable Room in Fulham                 |4.74                |
# |NULL     |Beautiful 1 bed apt in Queens Park               |4.88                |
# |76.0     |Room with a garden                               |5.0                 |
# +---------+-------------------------------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### SEARCHING FOR GOOD AND CHEAP LOCATIONS IN THE LISTING DATA

# %%
from pyspark.sql import functions as F

rare_gems = (
    price_num_df
    .filter((F.col("price_num") < 80) & (F.col("review_scores_rating") > 4))
    .select("id", F.col("price_num").alias("PRICE"), "name", "review_scores_rating")
)

rare_gems.show(20, truncate=False)
# Out:
# +------+-----+-------------------------------------------------+--------------------+
# |id    |PRICE|name                                             |review_scores_rating|
# +------+-----+-------------------------------------------------+--------------------+
# |13913 |70.0 |Holiday London DB Room Let-on going              |4.85                |
# |38605 |61.0 |SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST       |4.77                |
# |38995 |49.0 |SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT         |4.97                |
# |42010 |71.0 |You Will Save Money Here                         |4.89                |
# |43129 |48.0 |Quiet Comfortable Room in Fulham                 |4.74                |
# |45163 |76.0 |Room with a garden                               |5.0                 |
# |47192 |50.0 |Pleasant Single Room in zone 1.                  |4.81                |
# |47687 |78.0 |Cosy Double studio in Zone 2 Hammersmith (6)     |4.73                |
# |49970 |79.0 |Beautiful Small Studio Hammersmith               |4.71                |
# |56229 |78.0 |Cosy Double studio in Zone 2 Hammersmith (1)     |4.71                |
# |66772 |79.0 |Cosy Double studio in Zone 2 Hammersmith (3)     |4.69                |
# |67934 |40.0 |NICE FAMILY HOME opposite NATURAL LANDSCAPED PARK|4.54                |
# |69198 |53.0 |Spacious single room in quiet flat               |4.46                |
# |79129 |35.0 |Double Room 2 Miles from Wimbledon in Morden SM4 |4.9                 |
# |83027 |43.0 |Spacious Bright Room in SE3                      |4.5                 |
# |84223 |57.0 |Designer room Park Views 4 mins zone 1 station   |4.79                |
# |85191 |75.0 |Maisonette in Central London Zone 1              |4.86                |
# |97506 |60.0 |Lovely Victorian Room Streatham                  |4.86                |
# |106332|55.0 |Lovely large room, Bethnal Green                 |4.84                |
# |116268|36.0 |Double Room (Unavailable for check in 9-11 July) |4.9                 |
# +------+-----+-------------------------------------------------+--------------------+
# only showing top 20 rows

# %%
listings\
    .select(listings.property_type,listings.room_type)\
    .distinct()\
    .show(truncate=False)

# %% [markdown]
# ##### GETTING HOUSES THAT HAVE NO PICTURE URL AND THEIR PERFORMANCE IN TERMS OF RATING

# %%
listings.select(
    F.min("review_scores_rating").alias("min"),
    F.max("review_scores_rating").alias("max")
).show()

# %%
listings\
 .filter(
     (F.col("picture_url").isNull() | (F.trim(F.col("picture_url")) == ""))
     ##(F.col("review_scores_rating") < 3)
 )\
.select("id", "name", "room_type",F.col("picture_url").alias("URL"), "review_scores_rating")\
 .show(truncate=False)

# %% [markdown]
# ##### NUMBER OF PROPERTIES THAT GET MORE THAN 10 REVIEWS PER MONTH

# %%
listings\
    .filter(F.col("reviews_per_month") > 10) \
    .select("id","name","room_type","reviews_per_month") .distinct() \
    .show(truncate=False)

# %% [markdown]
# ##### Properties that have more bathrooms than bedrooms and their review ratings

# %%
listings\
    .filter(F.col("bathrooms")>F.col("bedrooms"))\
    .select("id","name","room_type","bathrooms","bedrooms","review_scores_rating")\
    .show(truncate=False)
# Out:
# +------+-------------------------------------------------+---------------+---------+--------+--------------------+
# |id    |name                                             |room_type      |bathrooms|bedrooms|review_scores_rating|
# +------+-------------------------------------------------+---------------+---------+--------+--------------------+
# |56229 |Cosy Double studio in Zone 2 Hammersmith (1)     |Entire home/apt|1.5      |1       |4.71                |
# |81951 |LONDON DETACHED HOUSE*ElecGates etc              |Entire home/apt|2.0      |1       |NULL                |
# |84223 |Designer room Park Views 4 mins zone 1 station   |Private room   |1.5      |1       |4.79                |
# |85191 |Maisonette in Central London Zone 1              |Private room   |1.5      |1       |4.86                |
# |157714|West London,loft ensuite, 5min2tube              |Private room   |1.5      |1       |4.7                 |
# |227502|Shoreditch Loft                                  |Entire home/apt|1.5      |1       |4.41                |
# |236956|Five minute walk to South Bank                   |Private room   |1.5      |1       |4.63                |
# |243093|Stunning double room own bathroom                |Private room   |4.0      |1       |4.82                |
# |268398|Also five minutes to South Bank                  |Private room   |1.5      |1       |4.63                |
# |273941|Studio 20 min from center                        |Entire home/apt|1.0      |0       |4.55                |
# |283569|Spacious luxury 2 bedroom apartment              |Entire home/apt|1.5      |1       |4.6                 |
# |289802|Single room near Canning Town (7 mins by bus)    |Private room   |1.5      |1       |4.83                |
# |331058|Spacious Double Room (R3)                        |Private room   |2.0      |1       |4.55                |
# |334310|Superior Boutique Comfort, Amazing Fast Transport|Private room   |2.0      |1       |4.84                |
# |341779|NICE DOUBLE ROOM IN A CLEAN  AND QUIET HOUSE     |Private room   |1.5      |1       |4.58                |
# |344094|Homely Twin Room Streatham,London                |Private room   |1.5      |1       |4.73                |
# |344102|Homely Triple Room London 2                      |Private room   |1.5      |0       |4.78                |
# |346523|Luxury, Newly Renovated Chelsea Apartment        |Entire home/apt|2.5      |2       |4.79                |
# |348215|Gorgeous double at Camden Market                 |Private room   |1.5      |1       |4.92                |
# |377707|Vintage Oasis and Double Room and Peace          |Private room   |1.0      |0       |4.88                |
# +------+-------------------------------------------------+---------------+---------+--------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ##### PROPERTIES WITH PRICES GREATER THAN PRICES THAN 5,000

# %%
price_num_df\
    .filter(F.col("price_num")>5000)\
    .select("id","price","name","review_scores_rating")\
    .show(10,truncate=False)
# Out:
# +--------+----------+--------------------------------------------------+--------------------+
# |id      |price     |name                                              |review_scores_rating|
# +--------+----------+--------------------------------------------------+--------------------+
# |9470827 |$8,000.00 |Room in a cosy flat. Central, clean               |4.75                |
# |10475894|$6,309.00 |Spacious Private Ground Floor Room                |NULL                |
# |13254774|$53,588.00|No Longer Available                               |4.85                |
# |13841484|$74,100.00|Bright & airy DoubleBed with EnSuite in Zone 2!   |4.89                |
# |36304412|$7,377.00 |The Apartments by The Sloane Club, Two Bedroom Apt|NULL                |
# |36304540|$7,377.00 |The Apartments by The Sloane Club, L 2 Bedroom Apt|NULL                |
# |40881056|$6,523.00 |Single room. 7ft x 9ft - Over looking garden      |NULL                |
# |41559554|$6,666.00 |Close To London Eye (TUR)                         |4.26                |
# |48043486|$6,000.00 |Beautiful 2 BR flat in Kilburn with free parking  |NULL                |
# |48118935|$7,019.00 |Semi-detached mews house in Knightsbridge.        |NULL                |
# +--------+----------+--------------------------------------------------+--------------------+
# only showing top 10 rows

# %%
(price_num_df
 .filter(
     (F.col("price_num") < 150) &
     (F.col("review_scores_rating") > 4.5) &
     (F.col("number_of_reviews") > 20)
 )
 .select("id","name","price","review_scores_rating","number_of_reviews") \
 .show(truncate=False)
)
# Out:
# +-----+-------------------------------------------------+-------+--------------------+-----------------+
# |id   |name                                             |price  |review_scores_rating|number_of_reviews|
# +-----+-------------------------------------------------+-------+--------------------+-----------------+
# |13913|Holiday London DB Room Let-on going              |$70.00 |4.85                |55               |
# |15400|Bright Chelsea  Apartment. Chelsea!              |$149.00|4.8                 |97               |
# |36660|You are GUARANTEED to love this                  |$90.00 |4.87                |730              |
# |38605|SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST       |$61.00 |4.77                |387              |
# |38995|SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT         |$49.00 |4.97                |72               |
# |41712|Room with a view, shared flat,  central  Bankside|$96.00 |4.7                 |137              |
# |42010|You Will Save Money Here                         |$71.00 |4.89                |639              |
# |43129|Quiet Comfortable Room in Fulham                 |$48.00 |4.74                |266              |
# |47192|Pleasant Single Room in zone 1.                  |$50.00 |4.81                |456              |
# |47687|Cosy Double studio in Zone 2 Hammersmith (6)     |$78.00 |4.73                |221              |
# |49970|Beautiful Small Studio Hammersmith               |$79.00 |4.71                |263              |
# |56229|Cosy Double studio in Zone 2 Hammersmith (1)     |$78.00 |4.71                |173              |
# |63948|Cosy Double studio in Zone 2 Hammersmith (4)     |$89.00 |4.63                |227              |
# |66772|Cosy Double studio in Zone 2 Hammersmith (3)     |$79.00 |4.69                |229              |
# |67934|NICE FAMILY HOME opposite NATURAL LANDSCAPED PARK|$40.00 |4.54                |25               |
# |73431|2 bed/2 bath luxury flat with city view!         |$117.00|4.9                 |110              |
# |79129|Double Room 2 Miles from Wimbledon in Morden SM4 |$35.00 |4.9                 |169              |
# |80123|Pretty Self Contained Coach House                |$110.00|4.92                |178              |
# |81635|Clerkenwell penthouse, huge terrace              |$125.00|4.95                |77               |
# |84223|Designer room Park Views 4 mins zone 1 station   |$57.00 |4.79                |460              |
# +-----+-------------------------------------------------+-------+--------------------+-----------------+
# only showing top 20 rows

# %%
listings \
    .groupby(listings.property_type) \
    .count() \
    .show(truncate=False)
